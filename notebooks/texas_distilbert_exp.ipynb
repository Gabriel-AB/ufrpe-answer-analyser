# %% [markdown]
# <a href="https://colab.research.google.com/github/ufrpe-bcc-ia/projetos-hyan/blob/main/notebooks/texas_distilbert_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive');

# %%
DATASET = '/content/drive/MyDrive/Research/Projeto Correção de questão/Data/TexasDataset/EXCEL/texas_dataset.xlsx'
TARGET = 'input'
TEST_SIZE = 0.2
SEED = 42

# %%
# %%capture
# !pip install datasets

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import warnings
import joblib
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModel
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, cohen_kappa_score
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from tqdm.notebook import tqdm_notebook

# %%
warnings.filterwarnings("ignore")

# %%
sns.set_theme(style='darkgrid')
tqdm_notebook.pandas()

# %%
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
  torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# # Data Analysis

# %%
columns_dict = {
  "Topic": "topic",
  "Human Evaluation": "human_evaluation",
  "Round_score": "human_evaluation",
  "Question": "question",
  "Student Answer": "answer",
  "Question_ID": "question_id",
  "Score": "score"
}

# %%
dataset = pd.read_excel(DATASET)
dataset.rename(columns=columns_dict, inplace=True)
dataset.head()
# Out:
#    ID question_id                                           question  \
# 0   1  2023-01-01   What is the role of a prototype program in pr...
# 1   2  2023-01-01   What is the role of a prototype program in pr...
# 2   3  2023-01-01   What is the role of a prototype program in pr...
# 3   4  2023-01-01   What is the role of a prototype program in pr...
# 4   5  2023-01-01   What is the role of a prototype program in pr...
#
#                                   Instructor answers  \
# 0   To simulate the behaviour of portions of the ...
# 1   To simulate the behaviour of portions of the ...
# 2   To simulate the behaviour of portions of the ...
# 3   To simulate the behaviour of portions of the ...
# 4   To simulate the behaviour of portions of the ...
#
#                                               answer  score  human_evaluation
# 0   High risk problems are address in the prototy...    3.5                 4
# 1   To simulate portions of the desired final pro...    5.0                 5
# 2   A prototype program simulates the behaviors o...    4.0                 4
# 3   Defined in the Specification phase a prototyp...    5.0                 5
# 4   It is used to let the users have a first idea...    3.0                 3

# %% [markdown]
# ## Data split

# %%
X = dataset.drop("human_evaluation", axis=1)
y = dataset["human_evaluation"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, stratify=dataset["human_evaluation"], shuffle=True, random_state=SEED)
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (1953, 489, 1953, 489)

# %% [markdown]
# ## Training set

# %% [markdown]
# ### Solving the unbalanced data problem

# %%
train_set = pd.concat([X_train, y_train], axis=1)
train_set.head()
# Out:
#         ID question_id                                           question  \
# 962    963  2023-01-06                                 What is a pointer?
# 2194  2195  2023-02-12  What is the experimental approach for measurin...
# 46      47  2023-02-01   What stages in the software life cycle are in...
# 1426  1427  2023-05-08  Which implementation (array-based vs. list-bas...
# 2441  2442  2023-10-12  How many steps does it take to search a node i...
#
#                                      Instructor answers  \
# 962   A variable that contains the address in memory...
# 2194  Implement the algorithm and measure the physic...
# 46     The testing stage can influence both the codi...
# 1426  Link-based, because they are dynamic (no size ...
# 2441                            The height of the tree.
#
#                                                  answer  score  \
# 962   It is like a variable however instead of holdi...    4.5
# 2194  Experimental means you would actually write a ...    5.0
# 46     Depending on how the work is done, Testing is...    1.5
# 1426  Array-based prevents the push operation  from ...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#       human_evaluation
# 962                  5
# 2194                 5
# 46                   2
# 1426                 5
# 2441                 2

# %%
label_5_ds = train_set[train_set["human_evaluation"] == 5]
label_5_ds = pd.concat([label_5_ds] * 1, axis=0, ignore_index=True)

label_4_ds = train_set[train_set["human_evaluation"] == 4]
label_4_ds = pd.concat([label_4_ds] * 4, axis=0, ignore_index=True)

label_3_ds = train_set[train_set["human_evaluation"] == 3]
label_3_ds = pd.concat([label_3_ds] * 5, axis=0, ignore_index=True)

label_2_ds = train_set[train_set["human_evaluation"] == 2]
label_2_ds = pd.concat([label_2_ds] * 10, axis=0, ignore_index=True)

label_1_ds = train_set[train_set["human_evaluation"] == 1]
label_1_ds = pd.concat([label_1_ds] * 50, axis=0, ignore_index=True)

label_0_ds = train_set[train_set["human_evaluation"] == 0]
label_0_ds = pd.concat([label_0_ds] * 53, axis=0, ignore_index=True)

train_set = pd.concat([label_0_ds, label_1_ds, label_2_ds, label_3_ds, label_4_ds, label_5_ds], axis=0)
len(train_set)
# Out:
# 6902

# %%
train_set = train_set.sample(frac=1, random_state=SEED).reset_index(drop=True)
train_set.head()
# Out:
#      ID question_id                                           question  \
# 0  1223  2023-04-07  How are linked lists passed as arguments to a ...
# 1  1777  2023-04-10                             What is a binary tree?
# 2  2240  2023-03-12  Order the following functions by their running...
# 3   690  2023-02-04  What is the main difference between strings de...
# 4  2422  2023-10-12  How many steps does it take to search a node i...
#
#                                   Instructor answers  \
# 0                                      By reference.
# 1  A tree for which the maximum number of childre...
# 2             log(log n);  2^(log n) ; n^2 ; n^3; n!
# 3  The strings declared using an array of charact...
# 4                            The height of the tree.
#
#                                               answer  score  human_evaluation
# 0                                       not answered    0.0                 0
# 1  A binary search tree is a tree that also has t...    4.5                 5
# 2  longest to shortest:<br>n^3; n!; n^2; 2^(log n...    3.0                 3
# 3  array  it is the collection of similar data ty...    2.5                 3
# 4  2^n where n is the # of levels the binary tree...    2.0                 2

# %%
train_set['answer'] = train_set['answer'].astype(str)
train_set['question'] = train_set['question'].astype(str)
train_set['question_id'] = train_set['question_id'].astype(str)
train_set.drop("score", inplace=True, axis=1)

# %%
train_set.dropna(inplace=True)
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6902 entries, 0 to 6901
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  6902 non-null   int64
#  1   question_id         6902 non-null   object
#  2   question            6902 non-null   object
#  3   Instructor answers  6902 non-null   object
#  4   answer              6902 non-null   object
#  5   human_evaluation    6902 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 323.7+ KB

# %%
plt.figure(figsize=(8, 4))
train_set['human_evaluation'].value_counts(ascending=True).plot.barh(color='skyblue')
plt.title('Training Human Evaluation Distribution')
plt.xlabel('Frequency')
plt.ylabel('Evaluations')
plt.show()

# %% [markdown]
# ## Testing Set

# %%
test_set = pd.concat([X_test, y_test], axis=1)
test_set.head()
# Out:
#         ID question_id                                           question  \
# 1111  1112  2023-07-06                        What is a function pointer?
# 1038  1039  2023-04-06  How can an array be addressed in pointer/offse...
# 11      12  2023-01-01   What is the role of a prototype program in pr...
# 1724  1725  2023-02-10                      What is the height of a tree?
# 1476  1477  2023-06-08  How are infix expressions evaluated by computers?
#
#                                      Instructor answers  \
# 1111  The address of the location in memory where th...
# 1038  By initializing a pointer to point to the firs...
# 11     To simulate the behaviour of portions of the ...
# 1724  The length of the longest path from the root t...
# 1476  First, they are converted into postfix form, f...
#
#                                                  answer  score  \
# 1111  A pointer to a function is the address where t...    5.0
# 1038  Element b[ n ] can be accessed by  *( bPtr + n...    4.5
# 11     A program that simulates the behavior of port...    5.0
# 1724  The height is the number of generations (level...    4.5
# 1476  they are transformed into post-fix expressions...    5.0
#
#       human_evaluation
# 1111                 5
# 1038                 5
# 11                   5
# 1724                 5
# 1476                 5

# %%
test_set['answer'] = test_set['answer'].astype(str)
test_set['question'] = test_set['question'].astype(str)
test_set['question_id'] = test_set['question_id'].astype(str)
test_set.drop('score', inplace=True, axis=1)

# %%
test_set.dropna(inplace=True)
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489 entries, 1111 to 44
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  489 non-null    int64
#  1   question_id         489 non-null    object
#  2   question            489 non-null    object
#  3   Instructor answers  489 non-null    object
#  4   answer              489 non-null    object
#  5   human_evaluation    489 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 26.7+ KB

# %%
plt.figure(figsize=(8, 4))
test_set['human_evaluation'].value_counts(ascending=True).plot.barh(color='skyblue')
plt.title('Testing Human Evaluation Distribution')
plt.xlabel('Frequency')
plt.ylabel('Evaluations')
plt.show()

# %% [markdown]
# ## All dataset

# %%
dataset = pd.concat([train_set, test_set])
dataset.head()
# Out:
#      ID question_id                                           question  \
# 0  1223  2023-04-07  How are linked lists passed as arguments to a ...
# 1  1777  2023-04-10                             What is a binary tree?
# 2  2240  2023-03-12  Order the following functions by their running...
# 3   690  2023-02-04  What is the main difference between strings de...
# 4  2422  2023-10-12  How many steps does it take to search a node i...
#
#                                   Instructor answers  \
# 0                                      By reference.
# 1  A tree for which the maximum number of childre...
# 2             log(log n);  2^(log n) ; n^2 ; n^3; n!
# 3  The strings declared using an array of charact...
# 4                            The height of the tree.
#
#                                               answer  human_evaluation
# 0                                       not answered                 0
# 1  A binary search tree is a tree that also has t...                 5
# 2  longest to shortest:<br>n^3; n!; n^2; 2^(log n...                 3
# 3  array  it is the collection of similar data ty...                 3
# 4  2^n where n is the # of levels the binary tree...                 2

# %%
dataset['answer'] = dataset['answer'].astype(str)
dataset['question'] = dataset['question'].astype(str)

# %%
dataset['words_per_question'] = dataset['question'].str.split().apply(len)
dataset.boxplot('words_per_question', by='human_evaluation', grid=False, color='black', showfliers=False)
plt.title('Words per Question')
plt.suptitle('')
plt.xlabel('Human Evaluations')
plt.ylabel('# of tokens')
plt.show()

# %%
dataset['words_per_answer'] = dataset['answer'].str.split().apply(len)
dataset.boxplot('words_per_answer', by='human_evaluation', grid=False, color='black', showfliers=False)
plt.title('Words per Answer')
plt.suptitle('')
plt.xlabel('Human Evaluations')
plt.ylabel('# of tokens')
plt.show()

# %% [markdown]
# # Training

# %%
if TARGET != 'answer':
    train_set['input'] = train_set.progress_apply(lambda row: row['question'] + ' ' + row['answer'], axis=1)
    test_set['input'] = test_set.progress_apply(lambda row: row['question'] + ' ' + row['answer'], axis=1)

display(train_set.head(2))
display(test_set.head(2))
# Out:
#   0%|          | 0/6902 [00:00<?, ?it/s]
#   0%|          | 0/489 [00:00<?, ?it/s]
#      ID question_id                                           question  \
# 0  1223  2023-04-07  How are linked lists passed as arguments to a ...
# 1  1777  2023-04-10                             What is a binary tree?
#
#                                   Instructor answers  \
# 0                                      By reference.
# 1  A tree for which the maximum number of childre...
#
#                                               answer  human_evaluation  \
# 0                                       not answered                 0
# 1  A binary search tree is a tree that also has t...                 5
#
#                                                input
# 0  How are linked lists passed as arguments to a ...
# 1  What is a binary tree? A binary search tree is...
#         ID question_id                                           question  \
# 1111  1112  2023-07-06                        What is a function pointer?
# 1038  1039  2023-04-06  How can an array be addressed in pointer/offse...
#
#                                      Instructor answers  \
# 1111  The address of the location in memory where th...
# 1038  By initializing a pointer to point to the firs...
#
#                                                  answer  human_evaluation  \
# 1111  A pointer to a function is the address where t...                 5
# 1038  Element b[ n ] can be accessed by  *( bPtr + n...                 5
#
#                                                   input
# 1111  What is a function pointer? A pointer to a fun...
# 1038  How can an array be addressed in pointer/offse...

# %% [markdown]
# ## Data Pre-processing

# %%
# Load the dataset
train_ds = Dataset.from_pandas(train_set, split='train')
test_ds = Dataset.from_pandas(test_set, split='test')
ds = DatasetDict()
ds['train'] = train_ds
ds['test'] = test_ds

# %%
# Load the tokenizer
model_ckpt = 'distilbert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

# %%
# Tokenizing a question
target = TARGET

ds.set_format(type='pandas')
text = ds['train'][:][target].iloc[0]
ds.reset_format()
encoded_text = tokenizer(text)
tokens = tokenizer.convert_ids_to_tokens(encoded_text['input_ids'])
tokenizer.convert_tokens_to_string(tokens)
# Out:
# '[CLS] how are linked lists passed as arguments to a function? not answered [SEP]'

# %%
# Model maximum context size and vocabulary size

tokenizer.model_max_length, tokenizer.vocab_size
# Out:
# (512, 30522)

# %%
def tokenize(tokenizer: AutoTokenizer, batch, target):
    return tokenizer(batch[target], padding=True, truncation=True)

# %%
target = TARGET
ds_encoded = ds.map(lambda batch: tokenize(tokenizer, batch, target), batched=True, batch_size=None)
# Out:
# Map:   0%|          | 0/6902 [00:00<?, ? examples/s]
# Map:   0%|          | 0/489 [00:00<?, ? examples/s]

# %%
ds_encoded['train'].column_names
# Out:
# ['ID',
#  'question_id',
#  'question',
#  'Instructor answers',
#  'answer',
#  'human_evaluation',
#  'input',
#  'input_ids',
#  'attention_mask']

# %% [markdown]
# ### BERT + classifier

# %%
model_ckpt = 'distilbert-base-uncased'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = AutoModel.from_pretrained(model_ckpt).to(device)

# %%
def extract_hidden_states(tokenizer: AutoTokenizer, model: AutoModel, batch, device):
    inputs = {
        k: v.to(device) for k, v in batch.items() if k in tokenizer.model_input_names
    }
    with torch.no_grad():
        last_hidden_state = model(**inputs).last_hidden_state
    return {"hidden_state": last_hidden_state[:, 0].cpu().numpy()}

# %%
target = TARGET
ds_encoded.set_format('torch', columns=['input_ids', 'attention_mask', target])
ds_hidden = ds_encoded.map(lambda batch: extract_hidden_states(tokenizer, model, batch, device), batched=True)
ds_hidden['train'].column_names
# Out:
# Map:   0%|          | 0/6902 [00:00<?, ? examples/s]
# Map:   0%|          | 0/489 [00:00<?, ? examples/s]
# ['ID',
#  'question_id',
#  'question',
#  'Instructor answers',
#  'answer',
#  'human_evaluation',
#  'input',
#  'input_ids',
#  'attention_mask',
#  'hidden_state']

# %%
X_train = np.array(ds_hidden['train']['hidden_state'])
y_train = np.array(ds_hidden['train']['human_evaluation'])
X_test = np.array(ds_hidden['test']['hidden_state'])
y_test = np.array(ds_hidden['test']['human_evaluation'])
X_train.shape, y_train.shape
# Out:
# ((6902, 768), (6902,))

# %% [markdown]
# #### Decision Tree Classifier

# %%
dtc = DecisionTreeClassifier(random_state=SEED)

dtc.fit(X_train, y_train)
dtc_y_pred = dtc.predict(X_test)
report = classification_report(y_test, dtc_y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       0.29      0.40      0.33         5
#            2       0.12      0.07      0.09        29
#            3       0.19      0.21      0.20        58
#            4       0.29      0.33      0.31        82
#            5       0.72      0.71      0.72       310
#
#     accuracy                           0.55       489
#    macro avg       0.41      0.45      0.43       489
# weighted avg       0.55      0.55      0.55       489

# %% [markdown]
# #### Random Forest Classification

# %%
rfc = RandomForestClassifier(n_estimators=400, random_state=SEED)

rfc.fit(X_train, y_train)
rfc_y_pred = dtc.predict(X_test)
report = classification_report(y_test, rfc_y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       0.29      0.40      0.33         5
#            2       0.12      0.07      0.09        29
#            3       0.19      0.21      0.20        58
#            4       0.29      0.33      0.31        82
#            5       0.72      0.71      0.72       310
#
#     accuracy                           0.55       489
#    macro avg       0.41      0.45      0.43       489
# weighted avg       0.55      0.55      0.55       489

# %% [markdown]
# #### Support Vector Classifier

# %%
svc = OneVsRestClassifier(
    SVR(
        kernel="rbf",
        gamma=0.1,
        coef0=0.0,
        C=1.0,
    )
)

svc.fit(X_train, y_train)
svc_y_pred = svc.predict(X_test)
report = classification_report(y_test, svc_y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.50      0.40      0.44         5
#            2       0.43      0.21      0.28        29
#            3       0.44      0.28      0.34        58
#            4       0.35      0.34      0.35        82
#            5       0.78      0.88      0.83       310
#
#     accuracy                           0.67       489
#    macro avg       0.58      0.52      0.54       489
# weighted avg       0.65      0.67      0.65       489

# %% [markdown]
# #### XGB Classifier

# %%
xgbc = XGBClassifier(random_state=SEED)
xgbc.fit(X_train, y_train)
xgbc_y_pred = xgbc.predict(X_test)
report = classification_report(y_test, xgbc_y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.67      0.40      0.50         5
#            2       0.20      0.03      0.06        29
#            3       0.48      0.17      0.25        58
#            4       0.40      0.30      0.35        82
#            5       0.72      0.92      0.81       310
#
#     accuracy                           0.67       489
#    macro avg       0.58      0.47      0.49       489
# weighted avg       0.61      0.67      0.62       489

# %% [markdown]
# ### Model Evaluation

# %%
tfidf_svm_ovr_kappa = cohen_kappa_score(y_test, svc_y_pred)
tfidf_rf_kappa = cohen_kappa_score(y_test, rfc_y_pred)
tfidf_tree_kappa = cohen_kappa_score(y_test, dtc_y_pred)
tfidf_xgb_kappa = cohen_kappa_score(y_test, xgbc_y_pred)

# %%
kappas = {
    "distilbert_svm_ovr_kappa": distilbert_svm_ovr_kappa,
    "distilbert_rf_kappa": distilbert_rf_kappa,
    "distilbert_tree_kappa": distilbert_tree_kappa,
    "distilbert_xgb_kappa": distilbert_xgb_kappa
}

kappas_df = pd.DataFrame(data=[kappas]).T.reset_index()
kappas_df.columns = ["Metric", "Score"]
kappas_df
# Out:
#                 Metric     Score
# 0  tfidf_svm_ovr_kappa  0.358987
# 1       tfidf_rf_kappa  0.188068
# 2     tfidf_tree_kappa  0.188068
# 3      tfidf_xgb_kappa  0.285062

# %%
joblib.dump(svc, "svm_ovr_model.pkl")
# Out:
# ['svm_ovr_model.pkl']
